# %% [markdown]
# <a href="https://colab.research.google.com/github/davidofitaly/course_notes_data-science-bootcamp-w-j-zyku-python---od-A-do-Z-12.5h-/blob/main/03_wizualizacje_danych/02_matplotlib_wykresy_s%C5%82upkowe_i_punktowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set()

# %% [markdown]
# WYKRESY SŁUPKOWE

# %%
plt.bar(x=[0,1,2,3], height=[10,20,30,5])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x=['a', 'b', 'c'],height=[1.2, 2.4, 4.8])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.barh(y=['a', 'b', 'c', 'd'], width=[10,2,5,0])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# WYKRESY PUNKTOWE

# %%
x1 = np.random.randn(300)
x2 = np.random.randn(300)
x3 = np.random.randn(300) *50
plt.scatter(x1,x2, s=x3)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.scatter(x1,x2, s=x3, alpha=0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
